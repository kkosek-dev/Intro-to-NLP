# %%
# Dependencies
import splinter
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

# %%
# Initialize Browser session
browser = Browser('chrome')

# %%
urls
# Out:
# ['https://www.walmart.com/reviews/product/389642865?filter=5&page=2',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=3',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=4',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=5',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=6',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=7',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=8',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=9']

# %%
# RESTART
df = pd.DataFrame()

# %%
# Specify an inidividual Walmart link for testing
website = 'https://www.walmart.com/reviews/product/389642865?filter=5&page=7'
# Visit website in our Browser session
browser.visit(website)
# Scrape the landing page html
# Use Beautiful soup to parse the webpage

# %%
html = browser.html
soup = BeautifulSoup(html,"html.parser")

# %%
# Initialize empty reviews list
review_list = []
# Save all of the review containers into a list object
rows = soup.find_all("li", class_="dib w-100 mb3")

# Create a for loop to loop through the containers and pick up the data, text & rating
for i in rows: 
    try:
    # Save date text
        date = i.find('div', class_='f7 gray mt1').text
    # Save review text
    
        text = i.find('span', class_='tl-m mb3 db-m').text

    # Save stars text
        stars = i.find('span', class_='w_iUH7').text
    # Add info dict to the empty reviews_list
        review_list.append( {
            'date':date,
            'text':text,
            'stars':stars
            } )
    except AttributeError:
        pass
review_df = pd.DataFrame(review_list)
df = pd.concat([df,review_df])

# %%
browser.quit()

# %%
len(df)
# Out:
# 119

# %%
# Create a DataFrame to visualize our scraped data
pd.DataFrame(review_list)
# Out:
#           date                                               text  \
# 0    9/26/2023  This Vizio 4K UHD is easy to setup may take so...
# 1     9/8/2023  Love the size, the clarity and the sound…..ama...
# 2   11/28/2023  My last Vizio tv was a 37 inch I think. It was...
# 3   11/27/2023  I purchased the 65” Vizio 4K TV In part on the...
# 4    11/1/2023  I love Vizio that’s always my go to brand I ha...
# 5   11/22/2023  I ordered a Vizio 50" Class V-Series 4L UHD LE...
# 6    12/5/2023  It didn't work right out of the box. Nothing b...
# 7   12/24/2023  I ordered  75” Vizio TV and just put it up, bu...
# 8     2/7/2024  Unfortunately the tv fell on me after purchasi...
# 9    12/2/2023  Bought the 65inch Vizio online and it arrived ...
# 10    9/7/2023  From the moment the TV arrived, albeit quickly...
# 11    8/4/2023  Ordered a 75 inch television as soon as the dr...
# 12   8/11/2023  Came broken, still waiting on refund. Took for...
# 13   9/10/2023  Great TV, picture is great, not a fan of the l...
# 14  10/22/2023  If you buy a TV Get it from the store and don'...
# 15  10/14/2023  The tv was broke the delivery person wasn't ab...
# 16   9/13/2023  I'm a bit disappointed that I have to wait 48 ...
# 17  10/11/2023  I've always been a huge fan of Vizio TVs for y...
# 18    7/9/2023  Really outstanding performance, I've had one o...
# 19  10/11/2023  Great picture love different settings we like ...
#
#                       stars
# 0   5 out of 5 stars review
# 1   5 out of 5 stars review
# 2   5 out of 5 stars review
# 3   5 out of 5 stars review
# 4   1 out of 5 stars review
# 5   1 out of 5 stars review
# 6   1 out of 5 stars review
# 7   1 out of 5 stars review
# 8   1 out of 5 stars review
# 9   1 out of 5 stars review
# 10  1 out of 5 stars review
# 11  1 out of 5 stars review
# 12  1 out of 5 stars review
# 13  5 out of 5 stars review
# 14  1 out of 5 stars review
# 15  1 out of 5 stars review
# 16  1 out of 5 stars review
# 17  1 out of 5 stars review
# 18  5 out of 5 stars review
# 19  5 out of 5 stars review

# %%
range_ = range(10)
counter = 0
for i in range_:
    if counter <2:
        print("A")
        counter +=1 
    else: 
        print("B")
# Out:
# A
# A
# B
# B
# B
# B
# B
# B
# B
# B

# %%
# Initialize Browser session

# %%
pd.DataFrame(review_list)
# Out:
#           date                                               text  \
# 0   11/28/2023  My last Vizio tv was a 37 inch I think. It was...
# 1   11/27/2023  I purchased the 65” Vizio 4K TV In part on the...
# 2    9/26/2023  This Vizio 4K UHD is easy to setup may take so...
# 3     9/8/2023  Love the size, the clarity and the sound…..ama...
# 4    9/10/2023  Great TV, picture is great, not a fan of the l...
# 5     7/9/2023  Really outstanding performance, I've had one o...
# 6   10/11/2023  Great picture love different settings we like ...
# 7   11/16/2023  TV is very sturdy. It has some weight to it, b...
# 8    11/5/2023  I liked the updates and the map showing where ...
# 9    10/8/2023  I like ho light in weight. The picture gives a...
# 10   8/22/2023  Great product, I've always loved Vizio product...
# 11   9/22/2023  Amazing TV and  great price! Im so happy with ...
# 12   1/14/2024  This 50in Vizio smart tv is a great choice if ...
# 13  11/14/2023  Once having a Google screen, and inspired by f...
# 14   3/15/2023  Easy to buy. Easy to load. Easy to mount. It's...
# 15   3/13/2023  Love the new added features they have availabl...
# 16   2/11/2024  Perfect TV and size. Was supposed to come on S...
# 17  11/18/2023  What sold me on this tv was the Bluetooth head...
# 18  11/12/2023  If you're looking for a great quality easy set...
# 19   1/26/2024  With 4K resolution, it really stands out if yo...
#
#                       stars
# 0   5 out of 5 stars review
# 1   5 out of 5 stars review
# 2   5 out of 5 stars review
# 3   5 out of 5 stars review
# 4   5 out of 5 stars review
# 5   5 out of 5 stars review
# 6   5 out of 5 stars review
# 7   5 out of 5 stars review
# 8   5 out of 5 stars review
# 9   5 out of 5 stars review
# 10  5 out of 5 stars review
# 11  5 out of 5 stars review
# 12  5 out of 5 stars review
# 13  5 out of 5 stars review
# 14  5 out of 5 stars review
# 15  5 out of 5 stars review
# 16  5 out of 5 stars review
# 17  5 out of 5 stars review
# 18  5 out of 5 stars review
# 19  5 out of 5 stars review

# %%
filter_ = 5
website = f'https://www.walmart.com/reviews/product/389642865?filter={filter_}'
browser = Browser('chrome')

# %%
browser.visit(website)

# %%
filter_ = 5
page_num_list = list(range(10))
page_num_list = page_num_list[2:]
urls=[]

for i in page_num_list:
    base_url = f'https://www.walmart.com/reviews/product/389642865?filter={filter_}&page={i}'
    urls.append(base_url)

# %%
urls
# Out:
# ['https://www.walmart.com/reviews/product/389642865?filter=5&page=2',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=3',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=4',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=5',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=6',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=7',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=8',
#  'https://www.walmart.com/reviews/product/389642865?filter=5&page=9']

# %%
page_num_list = list(range(10))
page_num_list = page_num_list[8:]

for i in page_num_list:
    print(i)
# Out:
# 8
# 9

# %%
# RESTART
#df = pd.DataFrame()

# %%
import random
filter_ = 4
i=0
review_list=[]
last_page_num = int(round((len(df) / 20),0))

page_num_list = list(range(30))
page_num_list = page_num_list[(last_page_num+1):]

for i in page_num_list:
    
    if int(len(df)) < 20:
        browser = Browser('chrome')
        website = f'https://www.walmart.com/reviews/product/389642865?filter={filter_}'
        sleep(3)
        browser.visit(website)
        sleep(3)
        # browser.is_text_present('Customer')
        html = browser.html
        soup = BeautifulSoup(html,"html.parser")
        
        # Initialize empty reviews list
        review_list = []
        # Save all of the review containers into a list object
        rows = soup.find_all("li", class_="dib w-100 mb3")

        # Create a for loop to loop through the containers and pick up the data, text & rating
        for i in rows: 
            # Save date text
            date = i.find('div', class_='f7 gray mt1').text
            # Save review text
            text = i.find('span', class_='tl-m mb3 db-m').text
            # Save stars text
            stars = i.find('span', class_='w_iUH7').text
            # Add info dict to the empty reviews_list
            review_list.append( {
                'date':date,
                'text':text,
                'stars':stars
            } )
        review_df = pd.DataFrame(review_list)
        df = pd.concat([df, review_df])
        print(f"-- Length of df -- {len(df)} --")
        browser.quit()
        sleep(140)

    else:
        browser = Browser('chrome')
        website = f'https://www.walmart.com/reviews/product/389642865?filter={filter_}&page={i}'
        sleep(3)
        browser.visit(website)
        sleep(3)
       # browser.is_text_present('Customer')
        html = browser.html
        soup = BeautifulSoup(html,"html.parser")
        review_list = []
       # Save all of the review containers into a list object
        rows = soup.find_all("li", class_="dib w-100 mb3")

        # Create a for loop to loop through the containers and pick up the data, text & rating
        for i in rows: 
            try:
                # Save date text
                date = i.find('div', class_='f7 gray mt1').text
                # Save review text
                text = i.find('span', class_='tl-m mb3 db-m').text
                # Save stars text
                stars = i.find('span', class_='w_iUH7').text
                # Add info dict to the empty reviews_list
                review_list.append( {
                    'date':date,
                    'text':text,
                    'stars':stars
                } )

            except AttributeError:
                print("empty text")
        review_df = pd.DataFrame(review_list)
        df = pd.concat([df, review_df])
        print(f"-- Length of df -- {len(df)} --")
        browser.quit()
        sleep(140)
# Out:
# Exception ignored in: <function Service.__del__ at 0x0000028063B26980>
# Traceback (most recent call last):
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\site-packages\selenium\webdriver\common\service.py", line 189, in __del__
#     self.stop()
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\site-packages\selenium\webdriver\common\service.py", line 146, in stop
#     self.send_remote_shutdown_command()
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\site-packages\selenium\webdriver\common\service.py", line 126, in send_remote_shutdown_command
#     request.urlopen(f"{self.service_url}/shutdown")
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 1377, in http_open
#     return self.do_open(http.client.HTTPConnection, req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\urllib\request.py", line 1348, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 1294, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 1340, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 1289, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 1048, in _send_output
#     self.send(msg)
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 986, in send
#     self.connect()
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\http\client.py", line 952, in connect
#     self.sock = self._create_connection(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karso\anaconda3\envs\bootcampDev\Lib\socket.py", line 843, in create_connection
#     exceptions.clear()  # raise only the last error
#     ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 32
#      30 date = i.find('div', class_='f7 gray mt1').text
#      31 # Save review text
# ---> 32 text = i.find('span', class_='tl-m mb3 db-m').text
#      33 # Save stars text
#      34 stars = i.find('span', class_='w_iUH7').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df = df.drop_duplicates()
display(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# SAVE
df.to_csv('data/scraped_4star_data.csv')

# %%
# Shape info
import numpy as np
np.shape(review_list)
# Out:
# (0,)

# %%
# Compile lists with websites for this method to loop through and scrape info

# %%
# End session
browser.quit()
